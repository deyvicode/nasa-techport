# %% [markdown]
# ## NASA Techport Projects

# %%
import pandas as pd
import api
import rs

resProjects = api.getProjectsSinceDate('2024-04-22')
dfProjectsRes = pd.DataFrame(resProjects)
dfProjectsRes.head()
# Out:
#   acronym  projectId title website lastUpdated
# 0              96770                 2024-4-23
# 1             154830                 2024-4-22
# 2             157150                 2024-4-22
# 3             157158                 2024-4-22
# 4             157154                 2024-4-22

# %%
#esta tarea tardara un poco...

def buildDataframe():

    dfProjects = pd.DataFrame(
        columns=[
            'project_id', 
            'acronym', 
            'title', 
            'description', 
            'start_year', 
            'start_month', 
            'end_year', 
            'end_month', 
            'status_description',
            'website',
            'last_updated',
            'release_status_string',
            'organization_id',
            'organization_name',
            'organization_type_pretty'
        ]
    )

    organizations = {}
            
    indexProject = 0

    for index, row in dfProjectsRes.iterrows():

        resProject = api.getProjectById(str(row['projectId']))

        organizationId = resProject['responsibleMd']['organizationId']
        organizationFound = organizations.get(organizationId)

        #add organization detail if not exists
        if organizationFound is None:
            resOrganization = api.getOrganizationById(str(organizationId))

            #append organization detail to dfOrganization
            organizations[organizationId] = {
                'organization_id': organizationId,
                'organization_name': resOrganization['organizationName'],
                'organization_type_pretty': resOrganization['organizationTypePretty']
            }

            organizationFound = organizations.get(organizationId)

        #add project to dfProjects
        dfProjects.loc[indexProject] = [
            resProject['projectId'],
            resProject['acronym'],
            resProject['title'],
            resProject['description'],
            resProject['startYear'],
            resProject['startMonth'],
            resProject['endYear'],
            resProject['endMonth'],
            resProject['statusDescription'],
            resProject['website'],
            resProject['lastUpdated'],
            resProject['releaseStatusString'],
            organizationFound['organization_id'],
            organizationFound['organization_name'],
            organizationFound['organization_type_pretty']
        ]

        indexProject += 1
        
    return dfProjects.drop_duplicates(subset=['project_id'], keep='last')

dfProjects = buildDataframe()
dfProjects.head()
# Out:
#    project_id acronym                                              title  \
# 0       96770  CASALS  SWaP-efficient, fast-wavelength-steering and t...
# 1      154830                                Radiation Tolerant Displays
# 2      157150                     CC22 NASA Particle Partition Challenge
# 3      157158               NASA Data Centers Energy Solutions Expertise
# 4      157154                                  CC23 Positive Connections
#
#                                          description  start_year  start_month  \
# 0  <p>We propose to integrate next-generation lid...        2018           10
# 1  <p>The Radiation Tolerant Displays project aim...        2022           10
# 2  <p>Currently under development at NASA, the Co...        2022            8
# 3  <p>NASA's Earth Science Division's Applied Sci...        2022            9
# 4  Under "Starburst: A Revolutionary Under-Constr...        2023            7
#
# ...

# %% [markdown]
# ## Redshift

# %%
loaded = rs.loadDataIntoRedshift(dfProjects)

if loaded:
    print("Data loaded into Redshift")
else:
    print("Data not loaded into Redshift")
# Out:
# - conectado a redshift
# - tabla projects eliminada
# - tabla projects creada
# - datos insertados en la tabla projects
# Data loaded into Redshift
